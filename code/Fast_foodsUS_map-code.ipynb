# %%
# importing the dependencies
import numpy as np 
import pandas as pd
import seaborn as sns
import geopandas as gpd
import folium
from folium import Choropleth, Circle, Marker
from folium.plugins import HeatMap, MarkerCluster
import math

# %%
# importing the data into Pandas
df = pd.read_csv("../data/Fast_Food_Restaurants_US.csv")

# %%
# dropping the colums not required for the cluster map
df_State= df.drop(columns=['Unnamed: 0','address','categories','city','country','postalCode','websites'])
df_State
# Out:
#        latitude  longitude            name province
# 0     29.814697 -90.814742  SONIC Drive In       LA
# 1     29.814697 -90.814742  SONIC Drive In       LA
# 2     35.803788 -83.580553       Taco Bell       TN
# 3     35.782339 -83.551408          Arby's       TN
# 4     33.562738 -84.321143  Steak 'n Shake       GA
# ...         ...        ...             ...      ...
# 9995  36.117563 -80.316553       Pizza Hut       NC
# 9996  36.077718 -80.176748       Pizza Hut       NC
# 9997  36.111015 -80.089165       Pizza Hut       NC
# 9998  35.719981 -77.945795       Pizza Hut       NC
# 9999  34.632778 -78.624615       Pizza Hut       NC
#
# [10000 rows x 4 columns]

# %%
# creating the map function
map_cluster = folium.Map(location=[40,-94], tiles='cartodbpositron', zoom_start=4)

# Add points to the map
mc = MarkerCluster()
# for loop to iterate over all the rows for the latitude and longitude
for idx, row in df_State.iterrows():
    if not math.isnan(row['longitude']) and not math.isnan(row['latitude']):
        iframe = folium.IFrame('Name: ' + str(row['name']))
        popup = folium.Popup(iframe, min_width=100, max_width=200)
        folium.Marker(location=[row['latitude'],row['longitude']],
                      popup = popup, c=row['name']).add_to(map)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_25392\1615632680.py in <module>
#      10         popup = folium.Popup(iframe, min_width=100, max_width=200)
#      11         folium.Marker(location=[row['latitude'],row['longitude']],
# ---> 12                       popup = popup, c=row['name']).add_to(map)
#      13
#      14
#
# ~\anaconda3\envs\PythonData\lib\site-packages\branca\element.py in add_to(self, parent, name, index)
#     134     def add_to(self, parent, name=None, index=None):
#     135         """Add element to a parent."""
# --> 136         parent.add_child(self, name=name, index=index)
#     137         return self
#     138
#
# AttributeError: type object 'map' has no attribute 'add_child'
