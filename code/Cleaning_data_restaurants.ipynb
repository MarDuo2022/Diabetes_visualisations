# %%
#import depedencies
import pandas as pd

# %%
#importing the dataFrames in Pandas
states_df = pd.read_csv("../data/statelatlong.csv")
restaurants_df = pd.read_csv("../data/FastFoodRestaurants.csv")
#Rename state names column for simplicity
states_df.rename(columns = {'City':'State'}, inplace = True)
dibeties_df = pd.read_csv("../data/Merged_data/US-CDI_diabetes_prevalence.csv")

# %%
restaurants_df.head()
# Out:
#                  address                    city country  \
# 0            324 Main St                 Massena      US
# 1        530 Clinton Ave  Washington Court House      US
# 2   408 Market Square Dr               Maysville      US
# 3  6098 State Highway 37                 Massena      US
# 4        139 Columbus Rd                  Athens      US
#
#                                                 keys  latitude  longitude  \
# 0                us/ny/massena/324mainst/-1161002137  44.92130  -74.89021
# 1  us/oh/washingtoncourthouse/530clintonave/-7914...  39.53255  -83.44526
# 2       us/ky/maysville/408marketsquaredr/1051460804  38.62736  -83.79141
# 3       us/ny/massena/6098statehighway37/-1161002137  44.95008  -74.84553
# 4               us/oh/athens/139columbusrd/990890980  39.35155  -82.09728
#
#                name postalCode province  \
# 0        McDonald's      13662       NY
# 1           Wendy's      43160       OH
# 2  Frisch's Big Boy      41056       KY
# ...

# %%
#Replacing all the symbols to get unique names as one string in names column and moving all vaules to upper case
restaurants_df['name'] = restaurants_df['name'].str.replace("’","")
restaurants_df['name'] = restaurants_df['name'].str.replace("'","")
restaurants_df['name'] = restaurants_df['name'].str.replace(" ","")
restaurants_df['name'] = restaurants_df['name'].str.replace(".","")
restaurants_df['name'] = restaurants_df['name'].str.replace("-","")
restaurants_df['name'] = restaurants_df['name'].str.replace("&","AND")
restaurants_df['name'] = restaurants_df['name'].str.upper()

# %%
#getting total counts of restaurants by state 
restaurants_df2 = restaurants_df['province'].value_counts().rename_axis('State').reset_index(name='counts')
restaurants_df2.sort_values(by='State').set_index('State').head()
# Out:
#        counts
# State
# AK         14
# AL        236
# AR        151
# AZ        208
# CA        676

# %%
#restaurants_df2.to_csv('restaurants_counts.csv')

# %%
dibeties_df.head()
# Out:
#    Unnamed: 0  yearstart locationabbr locationdesc  \
# 0        5841       2014           AK       Alaska
# 1        5927       2015           AK       Alaska
# 2        5869       2016           AK       Alaska
# 3        5926       2017           AK       Alaska
# 4        5856       2018           AK       Alaska
#
#                                             question datavalueunit  \
# 0  Prevalence of diagnosed diabetes among adults ...             %
# 1  Prevalence of diagnosed diabetes among adults ...             %
# 2  Prevalence of diagnosed diabetes among adults ...             %
# 3  Prevalence of diagnosed diabetes among adults ...             %
# 4  Prevalence of diagnosed diabetes among adults ...             %
#
#              datavaluetype  datavalue
# 0  Age-adjusted Prevalence        7.7
# 1  Age-adjusted Prevalence        7.8
# 2  Age-adjusted Prevalence        7.8
# 3  Age-adjusted Prevalence        7.6
# 4  Age-adjusted Prevalence        8.7

# %%
#Onlyselecting the rows for the year 2019
dibeties_df[dibeties_df['yearstart']==2019].head()
# Out:
#     Unnamed: 0  yearstart locationabbr locationdesc  \
# 5         5930       2019           AK       Alaska
# 11        5938       2019           AL      Alabama
# 17        6018       2019           AR     Arkansas
# 23        6199       2019           AZ      Arizona
# 29        6291       2019           CA   California
#
#                                              question datavalueunit  \
# 5   Prevalence of diagnosed diabetes among adults ...             %
# 11  Prevalence of diagnosed diabetes among adults ...             %
# 17  Prevalence of diagnosed diabetes among adults ...             %
# 23  Prevalence of diagnosed diabetes among adults ...             %
# 29  Prevalence of diagnosed diabetes among adults ...             %
#
#               datavaluetype  datavalue
# 5   Age-adjusted Prevalence        7.1
# 11  Age-adjusted Prevalence       12.2
# 17  Age-adjusted Prevalence       12.2
# 23  Age-adjusted Prevalence        9.8
# 29  Age-adjusted Prevalence        9.4
