# %%
# importing the dependencies
import pandas as pd

# %%
# importing the data into Pandas
df = pd.read_csv("../data/Fast_Food_Restaurants_US.csv")
df
# Out:
#       Unnamed: 0               address  \
# 0              0      800 N Canal Blvd
# 1              1      800 N Canal Blvd
# 2              2   206 Wears Valley Rd
# 3              3          3652 Parkway
# 4              4  2118 Mt Zion Parkway
# ...          ...                   ...
# 9995        9995     3460 Robinhood Rd
# 9996        9996  3069 Kernersville Rd
# 9997        9997         838 S Main St
# 9998        9998   1702 Glendale Dr SW
# 9999        9999       1405 W Broad St
#
#                                         categories           city country  \
# 0     American Restaurant and Fast Food Restaurant      Thibodaux      US
# 1                            Fast Food Restaurants      Thibodaux      US
# 2                             Fast Food Restaurant   Pigeon Forge      US
# 3                                        Fast Food   Pigeon Forge      US
# 4                             Fast Food Restaurant         Morrow      US
# ...

# %%
# dropping the colums not required for the cluster map
df_State= df.drop(columns=['Unnamed: 0','categories','city','country','postalCode','websites'])
df_State
# Out:
#                    address   latitude  longitude            name province
# 0         800 N Canal Blvd  29.814697 -90.814742  SONIC Drive In       LA
# 1         800 N Canal Blvd  29.814697 -90.814742  SONIC Drive In       LA
# 2      206 Wears Valley Rd  35.803788 -83.580553       Taco Bell       TN
# 3             3652 Parkway  35.782339 -83.551408          Arby's       TN
# 4     2118 Mt Zion Parkway  33.562738 -84.321143  Steak 'n Shake       GA
# ...                    ...        ...        ...             ...      ...
# 9995     3460 Robinhood Rd  36.117563 -80.316553       Pizza Hut       NC
# 9996  3069 Kernersville Rd  36.077718 -80.176748       Pizza Hut       NC
# 9997         838 S Main St  36.111015 -80.089165       Pizza Hut       NC
# 9998   1702 Glendale Dr SW  35.719981 -77.945795       Pizza Hut       NC
# 9999       1405 W Broad St  34.632778 -78.624615       Pizza Hut       NC
#
# [10000 rows x 5 columns]

# %%
df_State.to_csv('fast_food.csv',index=False)
